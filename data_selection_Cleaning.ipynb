# %%
import pandas as pd
import numpy as np

# %%
product_df = pd.read_csv("product_data.csv")
product_df.head(3)
# Out:
#    ProductID ProductName   Cost ShippingLocation SellerName
# 0          1       LEDTV  32990            Delhi    ABC Pvt
# 1          2     Printer   5990            Delhi    ABC Pvt
# 2          3    Split AC  32050             Pune    XY Corp

# %%
index = 2
product_df.loc[index]
# Out:
# ProductID                  3
# ProductName         Split AC
# Cost                   32050
# ShippingLocation        Pune
# SellerName           XY Corp
# Name: 2, dtype: object

# %%
product_df
# Out:
#    ProductID ProductName   Cost ShippingLocation SellerName
# 0          1       LEDTV  32990            Delhi    ABC Pvt
# 1          2     Printer   5990            Delhi    ABC Pvt
# 2          3    Split AC  32050             Pune    XY Corp
# 3          4   Microwave  12670           Mumbai    PQ Corp

# %%
product_df.iloc[:, 1:4]
# Out:
#   ProductName   Cost ShippingLocation
# 0       LEDTV  32990            Delhi
# 1     Printer   5990            Delhi
# 2    Split AC  32050             Pune
# 3   Microwave  12670           Mumbai

# %%
# -------------------------------------------------****------------------------------------------------

# %%
# -----------------------------------------Data Cleaing ----------------------------------------------------------

# %%
product_df.groupby('SellerName')

# %%
product_df.groupby("ProductName")["SellerName"].count()
# Out:
# ProductName
# LEDTV        1
# Microwave    1
# Printer      1
# Split AC     1
# Name: SellerName, dtype: int64

# %%
product_df.corr(numeric_only=True)
# Out:
#            ProductID      Cost
# ProductID   1.000000 -0.329618
# Cost       -0.329618  1.000000

# %%
#Sorting values
product_df.sort_values(by='Cost', ascending = False)
# Out:
#    ProductID ProductName   Cost ShippingLocation SellerName
# 0          1       LEDTV  32990            Delhi    ABC Pvt
# 2          3    Split AC  32050             Pune    XY Corp
# 3          4   Microwave  12670           Mumbai    PQ Corp
# 1          2     Printer   5990            Delhi    ABC Pvt

# %%
product_df.sort_values(by=['Cost', 'SellerName'], ascending = False)
# Out:
#    ProductID ProductName   Cost ShippingLocation SellerName
# 0          1       LEDTV  32990            Delhi    ABC Pvt
# 2          3    Split AC  32050             Pune    XY Corp
# 3          4   Microwave  12670           Mumbai    PQ Corp
# 1          2     Printer   5990            Delhi    ABC Pvt

# %%
product_df.dtypes
# Out:
# ProductID            int64
# ProductName         object
# Cost                 int64
# ShippingLocation    object
# SellerName          object
# dtype: object
